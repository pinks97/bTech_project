# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd ../
# Out:
# /content/drive/My Drive

# %%
# !ls
# Out:
#  annotation.zip   'btech project'      'Google Photos'	     training.ipynb
#  bdd100k	   colabintro.ipynb    'project (1).ipynb'   Untitled0.ipynb
#  bdd100k.ipynb	   darkflow	        project1.ipynb	     val_annotation.zip
# 'bdd annotation'   darkflowwww	        project.ipynb
#  bddtrain.ipynb   'Google colab.gdoc'   projectsss

# %%
# %cd drive/My Drive/darkflow
# Out:
# /content/drive/My Drive/darkflow

# %%
# !rm -R VOCdevkit

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/My%20Drive/darkflowwww
# ...
#   Running setup.py develop for darkflow
# ...

# %%
# !ls
# Out:
# cli.py	      dark	   __init__.py	__pycache__  version.py
# cython_utils  defaults.py  net		utils

# %%
# !unzip val_annotation.zip
# Out:
# Archive:  val_annotation.zip
#    creating: val_annotation/
#   inflating: val_annotation/b2c542e302f579a6.xml
#   inflating: val_annotation/b24f03f7ff66eaca.xml
#   inflating: val_annotation/c1a026fd6c19a089.xml
#   inflating: val_annotation/c43254a89aa667dc.xml
#   inflating: val_annotation/b242f6b20033bdfb.xml
#   inflating: val_annotation/bc5c87daf8979312.xml
#   inflating: val_annotation/c86482efb74850ca.xml
#   inflating: val_annotation/c20ae70fa8207705.xml
#   inflating: val_annotation/c909551efb24caeb.xml
#   inflating: val_annotation/c9b0aa6115573161.xml
#   inflating: val_annotation/be2c18495faf51d5.xml
#   inflating: val_annotation/b4253085d5fcbadc.xml
#   inflating: val_annotation/bc97328c1869fa3c.xml
#   inflating: val_annotation/bbe7c7e20d1dac56.xml
#   inflating: val_annotation/c11a0015fc7c0b35.xml
#   inflating: val_annotation/b3121071581b2755.xml
#   inflating: val_annotation/bf6e127b7d039d6b.xml
#   inflating: val_annotation/bb8dba979f4540b7.xml
# ...

# %%
# !git clone https://github.com/thtrieu/darkflow
# Out:
# Cloning into 'darkflow'...
# remote: Enumerating objects: 2706, done.
# remote: Total 2706 (delta 0), reused 0 (delta 0), pack-reused 2706
# Receiving objects: 100% (2706/2706), 18.74 MiB | 10.43 MiB/s, done.
# Resolving deltas: 100% (1781/1781), done.

# %%
# !wget https://archive.org/download/bdd100k/bdd100k_images.zip
# Out:
# --2019-03-17 18:00:23--  https://archive.org/download/bdd100k/bdd100k_images.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia902809.us.archive.org/21/items/bdd100k/bdd100k_images.zip [following]
# --2019-03-17 18:00:24--  https://ia902809.us.archive.org/21/items/bdd100k/bdd100k_images.zip
# Resolving ia902809.us.archive.org (ia902809.us.archive.org)... 207.241.232.109
# Connecting to ia902809.us.archive.org (ia902809.us.archive.org)|207.241.232.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6941520264 (6.5G) [application/zip]
# Saving to: ‘bdd100k_images.zip’
#
# bdd100k_images.zip  100%[===================>]   6.46G  1.99MB/s    in 98m 14s
#
# 2019-03-17 19:38:38 (1.12 MB/s) - ‘bdd100k_images.zip’ saved [6941520264/6941520264]

# %%
# %cd ../
# Out:
# /content/drive/My Drive

# %%
# !flow --pbLoad built_graph/yolo-voc.pb --metaLoad built_graph/yolo-voc.meta --imgdir sample_img/
# Out:
# /bin/bash: flow: command not found

# %%
# %cd darkflow
# Out:
# /content/drive/My Drive/darkflow

# %%
# %cd ../
# Out:
# /content/drive/My Drive

# %%
# %cd darkflow
# Out:
# /content/drive/My Drive/darkflow

# %%
# !flow --imgdir sample_img1/ --model cfg/yolov2.cfg --load bin/yolov2.weights --gpu 1.0
# Out:
# Parsing ./cfg/yolov2.cfg
# Traceback (most recent call last):
#   File "/usr/local/bin/flow", line 7, in <module>
#     exec(compile(f.read(), __file__, 'exec'))
#   File "/content/drive/My Drive/darkflowwww/flow", line 6, in <module>
#     cliHandler(sys.argv)
#   File "/content/drive/My Drive/darkflowwww/darkflow/cli.py", line 26, in cliHandler
#     tfnet = TFNet(FLAGS)
#   File "/content/drive/My Drive/darkflowwww/darkflow/net/build.py", line 58, in __init__
#     darknet = Darknet(FLAGS)
#   File "/content/drive/My Drive/darkflowwww/darkflow/dark/darknet.py", line 17, in __init__
#     src_parsed = self.parse_cfg(self.src_cfg, FLAGS)
#   File "/content/drive/My Drive/darkflowwww/darkflow/dark/darknet.py", line 68, in parse_cfg
#     for i, info in enumerate(cfg_layers):
#   File "/content/drive/My Drive/darkflowwww/darkflow/utils/process.py", line 66, in cfg_yielder
#     layers, meta = parser(model); yield meta;
# ...

# %%
# %cd bin
# Out:
# /content/drive/My Drive/darkflow/bin

# %%
# !wget https://github.com/pjreddie/darknet/blob/master/cfg/yolov2.cfg
# Out:
# --2019-03-29 09:36:53--  https://github.com/pjreddie/darknet/blob/master/cfg/yolov2.cfg
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘yolov2.cfg’
#
# yolov2.cfg              [  <=>               ] 111.60K   465KB/s    in 0.2s
#
# 2019-03-29 09:36:53 (465 KB/s) - ‘yolov2.cfg’ saved [114281]

# %%
# %cd  ..
# Out:
# /content/drive/My Drive/darkflow

# %%
# %cd cfg
# Out:
# /content/drive/My Drive/darkflow/cfg

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/My%20Drive/darkflow
# ...
#   Running setup.py develop for darkflow
# ...

# %%
# !flow --pbLoad built_graph/yolo-voc.pb --metaLoad built_graph/yolo-voc.meta --imgdir sample_img/ --threshold 0.025
# Out:
# /bin/bash: flow: command not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e6a34ba59b39> in <module>()
# ----> 1 get_ipython().system('flow --pbLoad built_graph/yolo-voc.pb --metaLoad built_graph/yolo-voc.meta --imgdir sample_img/ --threshold 0.025')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      71       kwargs.update({'also_return_output': True})
#      72
# ---> 73     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      74
#      75     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %%
# !flow --imgdir sample_img1/ --model cfg/yolov2.cfg --load bin/yolov2.weights --gpu 1.0
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# sh: 0: getcwd() failed: No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/flow", line 7, in <module>
#     exec(compile(f.read(), __file__, 'exec'))
#   File "/content/drive/My Drive/darkflowwww/flow", line 4, in <module>
#     from darkflow.cli import cliHandler
#   File "/content/drive/My Drive/darkflowwww/darkflow/cli.py", line 3, in <module>
#     from .net.build import TFNet
#   File "/content/drive/My Drive/darkflowwww/darkflow/net/build.py", line 1, in <module>
#     import tensorflow as tf
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/__init__.py", line 29, in <module>
#     from tensorflow._api.v1 import compat
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/_api/v1/compat/__init__.py", line 21, in <module>
#     from tensorflow._api.v1.compat import v1
# ...

# %%
# !ls
# Out:
# bin	     ckpt		flow	     README.md		test
# build	     darkflow		labels.txt   sample_img		video.avi
# built_graph  darkflow.egg-info	LICENSE      setup.py
# cfg	     demo.gif		preview.png  ShorterSample.mp4

# %%
# %cd ../
# Out:
# /content/drive/My Drive

# %%
# %cd darkflowwww/
# Out:
# [Errno 2] No such file or directory: 'darkflowwww/'
# /content/drive/My Drive/darkflowwww

# %%
# !ls
# Out:
# cfg	  demo.gif  labels.txt	preview.png  sample_img  test
# darkflow  flow	    LICENSE	README.md    setup.py

# %%
# !mkdir bin

# %%
# !flow --model ./cfg/yolov2-vocmine.cfg --load ./bin/yolov2-voc.weights --train --annotation val_annotation  --dataset val
# Out:
# Parsing ./cfg/yolov2-voc.cfg
# Parsing ./cfg/yolov2-vocmine.cfg
# Loading ./bin/yolov2-voc.weights ...
# Successfully identified 202704264 bytes
# Finished in 0.07542777061462402s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 64)
# ...
